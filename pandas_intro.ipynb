# %%
# exclamtion makes you run actual linux commands inside jupyter
! pip3 install pandas numpy --user

# %%
import datetime

help(datetime.timedelta)
# Out:
# Help on class timedelta in module datetime:
#
# class timedelta(builtins.object)
#  |  Difference between two datetime values.
#  |
#  |  timedelta(days=0, seconds=0, microseconds=0, milliseconds=0, minutes=0, hours=0, weeks=0)
#  |
#  |  All arguments are optional and default to 0.
#  |  Arguments may be integers or floats, and may be positive or negative.
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __bool__(self, /)
#  |      self != 0
#  |
#  |  __divmod__(self, value, /)
#  |      Return divmod(self, value).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __floordiv__(self, value, /)
#  |      Return self//value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
# ...

# %%
import datetime
import pandas as pd
import numpy as np

todays_date = datetime.datetime.now().date()
index = pd.date_range(todays_date - datetime.timedelta(10), periods=10, freq='D')

columns = ['A','B', 'C']

df_ = pd.DataFrame(index=index, columns=columns)
df_ = df_.fillna(0) # with 0s rather than NaNs

df_
# Out:
#             A  B  C
# 2021-05-22  0  0  0
# 2021-05-23  0  0  0
# 2021-05-24  0  0  0
# 2021-05-25  0  0  0
# 2021-05-26  0  0  0
# 2021-05-27  0  0  0
# 2021-05-28  0  0  0
# 2021-05-29  0  0  0
# 2021-05-30  0  0  0
# 2021-05-31  0  0  0

# %%
data = {
    'BTW': [3, 2, 0, 1], 
    'oranges': [0, 3, 7, 2]
}# dicts can even contain other dicts, like inception but with dicts and lists

purchases = pd.DataFrame(data)

purchases
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %%
purchases = pd.DataFrame(data, index=['Memo', 'Dinske', 'Janna', 'Lies']) # lets change the index

purchases
# Out:
#         apples  oranges
# Memo         3        0
# Dinske       2        3
# Janna        0        7
# Lies         1        2

# %%
purchases.loc['Memo'] # locate the specific purchase, this could have been an int aswell
# Out:
# apples     3
# oranges    0
# Name: Memo, dtype: int64

# %%
df = pd.read_csv('titanic.csv')

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df = df.rename(columns={
        'Survived': 'defo_not_dead', 
        'Embarked': 'gone'
    }, inplace=True)


df.columns
# Out:
# Index(['PassengerId', 'defo_not_dead', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'gone'],
#       dtype='object')

# %%
df.isnull().sum()
help(df.dropna)
# Out:
# Help on method dropna in module pandas.core.frame:
#
# dropna(axis=0, how='any', thresh=None, subset=None, inplace=False) method of pandas.core.frame.DataFrame instance
#     Remove missing values.
#
#     See the :ref:`User Guide <missing_data>` for more on which values are
#     considered missing, and how to work with missing data.
#
#     Parameters
#     ----------
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Determine if rows or columns which contain missing values are
#         removed.
#
#         * 0, or 'index' : Drop rows which contain missing values.
#         * 1, or 'columns' : Drop columns which contain missing value.
#
#         .. versionchanged:: 1.0.0
#
#            Pass tuple or list to drop on multiple axes.
#            Only a single axis is allowed.
#
#     how : {'any', 'all'}, default 'any'
#         Determine if row or column is removed from DataFrame, when we have
#         at least one NA or all NA.
#
# ...

# %%
df = df.dropna()
df = df.reset_index(drop=True)

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              2         1       1
# 1              4         1       1
# 2              7         0       1
# 3             11         1       3
# 4             12         1       1
# ..           ...       ...     ...
# 178          872         1       1
# 179          873         0       1
# 180          880         1       1
# 181          888         1       1
# 182          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 2                              McCarthy, Mr. Timothy J    male  54.0      0
# 3                      Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 4                             Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
subset = df[['Name', 'Sex']] ## df.loc['Prometheus':'Sing']
subset
# Out:
#                                                   Name     Sex
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 1         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 2                              McCarthy, Mr. Timothy J    male
# 3                      Sandstrom, Miss. Marguerite Rut  female
# 4                             Bonnell, Miss. Elizabeth  female
# ..                                                 ...     ...
# 178   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female
# 179                           Carlsson, Mr. Frans Olof    male
# 180      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female
# 181                       Graham, Miss. Margaret Edith  female
# 182                              Behr, Mr. Karl Howell    male
#
# [183 rows x 2 columns]

# %%
subset[subset['Sex'] == "female"]
# Out:
#                                                   Name     Sex
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 1         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 3                      Sandstrom, Miss. Marguerite Rut  female
# 4                             Bonnell, Miss. Elizabeth  female
# 8             Harper, Mrs. Henry Sleeper (Myna Haxtun)  female
# ..                                                 ...     ...
# 174                          Lines, Miss. Mary Conover  female
# 176  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female
# 178   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female
# 180      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female
# 181                       Graham, Miss. Margaret Edith  female
#
# [88 rows x 2 columns]

# %%
df[(df['Cabin'] == 'C85') | (df['Cabin'] == 'E46')].head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            2         1       1
# 2            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch    Ticket     Fare Cabin Embarked
# 0      0  PC 17599  71.2833   C85        C
# 2      0     17463  51.8625   E46        S

# %%
df[df['Cabin'].isin(['C85', 'E46'])].head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            2         1       1
# 2            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch    Ticket     Fare Cabin Embarked
# 0      0  PC 17599  71.2833   C85        C
# 2      0     17463  51.8625   E46        S

# %%
no_cheapskates = df.where(df.Fare > 100)
no_cheapskates.Fare.values
# Out:
# array([     nan,      nan,      nan,      nan,      nan,      nan,
#             nan, 263.    ,      nan,      nan,      nan,      nan,
#             nan, 263.    ,      nan,      nan,      nan,      nan,
#             nan, 247.5208,      nan,      nan,      nan,      nan,
#             nan,      nan,      nan,      nan,      nan,      nan,
#             nan,      nan,      nan, 146.5208,      nan,      nan,
#        113.275 ,      nan,      nan,      nan,      nan,      nan,
#             nan,      nan,      nan,      nan,      nan, 153.4625,
#        135.6333,      nan,      nan,      nan,      nan, 151.55  ,
#        247.5208, 151.55  , 108.9   ,      nan,      nan, 262.375 ,
#        164.8667, 134.5   , 135.6333,      nan,      nan,      nan,
#        153.4625,      nan, 134.5   ,      nan,      nan, 263.    ,
#             nan,      nan,      nan,      nan,      nan, 211.5   ,
#        120.    , 113.275 ,      nan,      nan,      nan,      nan,
# ...
